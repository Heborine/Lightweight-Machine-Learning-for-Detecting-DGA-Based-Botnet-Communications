# %% [markdown]
# # **Figure 7: ROC-AUC Curve**

# %% [markdown]
# Imports

# %%
from collections import Counter
from datetime import datetime
from dateutil import parser
from itertools import combinations
import kagglehub
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import math
import pandas as pd
import re
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import plot_tree
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, roc_curve, auc, confusion_matrix
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score

# %% [markdown]
# Download Benign Domains

# %%
cisco_path = kagglehub.dataset_download("adebayo/cisco-umbrella-list")
cisco_path += "/top-1m.csv"
print(cisco_path)
# Out:
# C:\Users\Admin\.cache\kagglehub\datasets\adebayo\cisco-umbrella-list\versions\1/top-1m.csv

# %% [markdown]
# Download Malicious DGA Domains

# %%
dga_path = kagglehub.dataset_download("gtkcyber/dga-dataset")
dga_path += "/dga_data.csv"
print(dga_path)
# Out:
# C:\Users\Admin\.cache\kagglehub\datasets\gtkcyber\dga-dataset\versions\1/dga_data.csv

# %% [markdown]
# Load Datasets

# %%
benign_domains = pd.read_csv(cisco_path, header=None)
benign_domains.columns = ["rank", "domain"]
benign_domains["label"] = 0

dga_domains = pd.read_csv(dga_path)
dga_domains["label"] = dga_domains["subclass"].apply(lambda x: 0 if x in ["alexa", "legit"] else 1)
# remove fake DGAs
dga_domains = dga_domains[dga_domains["label"] == 1]

print("Length of Benign Domain dataset:", len(benign_domains))
print("Length of DGA Domain dataset:", len(dga_domains))

benign_sample = benign_domains[["domain", "label"]]
dga_sample = dga_domains[["domain", "label"]]
benign_sampler = benign_domains[["domain", "label"]].sample(n=len(dga_sample), random_state=60)
df_full = pd.concat([benign_sample, dga_sample], ignore_index=True)
df = pd.concat([benign_sampler, dga_sample], ignore_index=True)
# Drop any rows with missing domains
print("Missing domains (benign):", benign_sample["domain"].isna().sum())
print("Missing domains (DGA):   ", dga_sample["domain"].isna().sum())
df = df.dropna(subset=["domain"]).reset_index(drop=True)
df["domain"] = df["domain"].astype(str).str.lower()
df_full = df_full.dropna(subset=["domain"]).reset_index(drop=True)
df_full["domain"] = df_full["domain"].astype(str).str.lower()

print("\nClass balance:")
print(df["label"].value_counts())
print(df["label"].value_counts(normalize=True).round(3))
# Out:
# Length of Benign Domain dataset: 1000000
# Length of DGA Domain dataset: 80000
# Missing domains (benign): 0
# Missing domains (DGA):    0
#
# Class balance:
# label
# 0    80000
# 1    80000
# Name: count, dtype: int64
# label
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %% [markdown]
# Extract Features

# %%
def shannon_entropy(s):
    """Measures randomness of characters in a string. Higher = more random."""
    if not s:
        return 0.0
    counts = Counter(s)
    length = len(s)
    return -sum((c/length) * math.log2(c/length) for c in counts.values())

def vowel_ratio(s):
    if not s:
        return 0.0
    vowels = sum(1 for ch in s if ch in "aeiou")
    letters = sum(1 for ch in s if ch.isalpha())
    return vowels / letters if letters else 0.0

def digit_ratio(s):
    if not s:
        return 0.0
    return sum(1 for ch in s if ch.isdigit()) / len(s)

def max_consecutive_consonants(s):
    rows = re.findall(r'[^aeiou\d\W_]+', s)
    maximum = max((len(r) for r in rows), default=0)
    return maximum

def hex_valid_ratio(s):
    if(not s):
        return 0
    return sum(1 for ch in s if ch in '0123456789abcdef') / len(s)

def is_dword_value(s):
    return int(bool(re.fullmatch(r'[0-9a-f]{8}', s)))

def max_consecutive_digits(s):
    rows = re.findall(r'\d+', s)
    maximum = max((len(r) for r in rows), default=0)
    return maximum

def is_punycode(domain):
    return int(any(label.startswith('xn--') for label in domain.split('.')))

def subdomain_count(domain):
    return len(domain.split('.')) - 1

# top-level domain
def tld_detection(df):
    tlds = df.groupby("tld")["label"]
    tld_counts = tlds.count()
    tld_sums = tlds.sum()
    # Laplace Smoothing - Benign and DGA (2)
    tld_malicious_laplace_smoothed = (tld_sums + 1) / (tld_counts + 2)
    return tld_malicious_laplace_smoothed
    # return df["tld"].map(tld_malicious_laplace_smoothed)

def has_embedded_date(s):
    no_date = datetime(1900, 1, 1)
    try:
        result = parser.parse(s, fuzzy=True, default=no_date)
        if(result.date() == no_date.date()):
            return 0
        return 1
    except (ValueError, parser.ParserError, OverflowError):
        return 0
    
def cons_vowel_transition_rate(s):
    def is_vowel(character):
        return (character in 'aeiou')
    
    # we want to ignore digits and hyphens
    alpha = [ch for ch in s if ch.isalpha()] 
    if(len(alpha) < 2):
        return 0.0
    curr_v = is_vowel(alpha[0])
    trans_count = 0
    if(curr_v):
        vowel_count = 1
    else:
        vowel_count = 0

    for ch in alpha[1:]:
        typing = is_vowel(ch)
        if(typing):
            vowel_count += 1
        # if a change in vowel to consonant or vice-versa, it is a transition
        if(typing != curr_v):
            trans_count += 1
            curr_v = typing

    if(vowel_count < 2):
        return 0.0
    return trans_count / (vowel_count - 1)

def char_class_entropy(s):
    def classify(ch):
        # if a vowel
        if(ch in 'aeiou'):
            return 'V'
        # otherwise if a letter, it is a consonant
        elif(ch.isalpha()):
            return 'C'
        # if it is a number
        elif(ch.isdigit()):
            return 'D'
        # if it is a special character, like a hyphen
        else:
            return 'H'
    classes = ''.join(classify(ch) for ch in s)
    return shannon_entropy(classes)

df["name"] = df["domain"].str.split(".").str[0]
df["tld"] = df["domain"].str.split(".").str[-1]
df_full["tld"] = df_full["domain"].str.split(".").str[-1]
df["length"] = df["name"].str.len()
df["entropy"] = df["name"].apply(shannon_entropy)
df["vowel_ratio"] = df["name"].apply(vowel_ratio)
df["digit_ratio"] = df["name"].apply(digit_ratio)
df["unique_chars"] = df["name"].apply(lambda s: len(set(s)))
df["hyphen_count"] = df["name"].str.count('-')
df["max_consec_cons"] = df["name"].apply(max_consecutive_consonants)
df["hex_ratio"] = df["name"].apply(hex_valid_ratio)
df["dword"] = df["name"].apply(is_dword_value)
df["max_consec_digit"] = df["name"].apply(max_consecutive_digits)
df["puny_code"] = df["domain"].apply(is_punycode)
df["subdomain_count"] = df["domain"].apply(subdomain_count)
tld_rates = tld_detection(df_full)
df["mal_tld"] = df["tld"].map(tld_rates).fillna(0.35)
df["embed_date"] = df["name"].apply(has_embedded_date)
df["cons_vowel_transition_rate"] = df["name"].apply(cons_vowel_transition_rate)
df["char_class_entropy"] = df["name"].apply(char_class_entropy)

# %%
def roc_auc_fpr(best_n_acc, best_n_prec, best_n_recall, best_n_f1, X_train, y_train, X_test, y_test):
    # complete ROC-AUC (theoretical capability measure of detecting DGAs) and False Positive Rate (practical deployability)
    fig, ax = plt.subplots(figsize=(8, 6))

    # plot a curve for each metric's best model
    for best_n, label, color in [
        (best_n_acc, "Accuracy", "blue"),
        (best_n_prec, "Precision", "green"),
        (best_n_recall, "Recall", "orange"),
        (best_n_f1, "F1 Score", "red")]:
        clf = RandomForestClassifier(n_estimators=best_n, random_state=60)
        clf.fit(X_train, y_train)
        # probability of a DGA class
        y_prob = clf.predict_proba(X_test)[:, 1]  
        y_pred = clf.predict(X_test)
        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
        # number of benign domains incorrectly flagged as DGA
        fpr0 = fp / (fp + tn)   
        # how many DGA domains were overlooked
        fnr = fn / (fn + tp)
        
        print(f"{label} (n={best_n}):")
        print(f"\tFalse Positive Rate: {fpr0:.5f} ({fpr0*100:.3f}%)")
        print(f"\tFalse Negative Rate: {fnr:.5f} ({fnr*100:.3f}%)")
        print(f"\tTrue Negatives={tn}, False Positives={fp}, False Negatives={fn}, True Positives={tp}\n")
        # fpr = false positive rates, tpr = true positive rates
        fpr, tpr, thresholds = roc_curve(y_test, y_prob)
        roc_auc = auc(fpr, tpr)
        ax.plot(fpr, tpr, color=color, label=f"{label} (AUC = {roc_auc:.3f})")

    # draw a line for the random classifier baseline
    ax.plot([0, 1], [0, 1], 'k--', label="Random Classifier (AUC = 0.50)")
    ax.set_xlabel("False Positive Rate", fontsize=13)
    ax.set_ylabel("True Positive Rate", fontsize=13)
    ax.set_title("ROC-AUC Curve", fontsize=16, fontweight="bold")
    ax.tick_params(labelsize=12)
    ax.legend(fontsize=11)
    ax.grid(True)
    if not hasattr(roc_auc_fpr, "_n"): roc_auc_fpr._n = 0
    roc_auc_fpr._n += 1
    _roc_sections = {1:"all16",2:"no_maltld",3:"no_maltld_sub",4:"charonly",5:"best_combo"}
    _roc_label = _roc_sections.get(roc_auc_fpr._n, str(roc_auc_fpr._n))
    plt.tight_layout()
    plt.savefig(f"../../figures/roc_auc.pdf", format="pdf", bbox_inches="tight")
    plt.show()

# %%
X = df[["length", "entropy", "vowel_ratio", "digit_ratio", "unique_chars", "hyphen_count", "max_consec_cons", "hex_ratio", "dword", "max_consec_digit", "puny_code", "subdomain_count", "mal_tld", "embed_date", "cons_vowel_transition_rate", "char_class_entropy"]]
y = df["label"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=60)

# %% [markdown]
# Find the best combination of features

# %% [markdown]
# Combinations without malicious TLD and subdomain count

# %%
features = ["length", "entropy", "vowel_ratio", "digit_ratio", "unique_chars", "hyphen_count", "max_consec_cons", "hex_ratio", "dword", "max_consec_digit", "puny_code", "embed_date"]

benign = df[df["label"] == 0].sample(n=25000, random_state=60)
dga = df[df["label"] == 1].sample(n=25000, random_state=60)
df_sample = pd.concat([benign, dga]).sample(frac=1, random_state=60)
# df_sample = df.sample(n=50000, random_state=60)
y = df_sample["label"]
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=60)
results = []
sample_n_estimators = 20
# test combinations of 3 to 8
for size in range(3, 9):
    for combo in combinations(features, size):
        X_sub = df_sample[list(combo)]
        clf = RandomForestClassifier(n_estimators=sample_n_estimators, random_state=60, n_jobs=-1)
        cv_scores = cross_val_score(clf, X_sub, y, cv=cv, scoring="f1", n_jobs=-1)
        mean_f1 = cv_scores.mean()
        results.append((mean_f1, combo))


results.sort(reverse=True)
print("15 best feature combinations:")
for score, combo in results[:15]:
    print(f"    F1 Score={score} | Length of Features:={len(combo)} | Features: {combo}")
# Out:
# 15 best feature combinations:
#     F1 Score=0.9260808372951365 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.926061867943344 | Length of Features:=6 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9260500443539608 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9260415183724102 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9260415037468439 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.9260408869824628 | Length of Features:=6 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9260407079388753 | Length of Features:=5 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9260199286156986 | Length of Features:=5 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.9260197810417129 | Length of Features:=4 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9259930937588781 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9259868887226169 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.9259867966786206 | Length of Features:=5 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9259843169511482 | Length of Features:=4 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons')
#     F1 Score=0.9259837573799532 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'puny_code', 'embed_date')
#     F1 Score=0.9259689121413966 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')

# %%
for score, combo in results:
    print(f"    F1 Score={score} | Length of Features:={len(combo)} | Features: {combo}")
# Out:
#     F1 Score=0.9260808372951365 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.926061867943344 | Length of Features:=6 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9260500443539608 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9260415183724102 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9260415037468439 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.9260408869824628 | Length of Features:=6 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9260407079388753 | Length of Features:=5 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9260199286156986 | Length of Features:=5 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.9260197810417129 | Length of Features:=4 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9259930937588781 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9259868887226169 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.9259867966786206 | Length of Features:=5 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9259843169511482 | Length of Features:=4 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons')
#     F1 Score=0.9259837573799532 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'puny_code', 'embed_date')
#     F1 Score=0.9259689121413966 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9259658356857339 | Length of Features:=5 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'embed_date')
#     F1 Score=0.9259624216897595 | Length of Features:=6 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9259621408166392 | Length of Features:=5 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9259478442741964 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'puny_code')
#     F1 Score=0.9259442386412123 | Length of Features:=7 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9259294828321272 | Length of Features:=5 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'puny_code')
#     F1 Score=0.9259198489539244 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9259111796649486 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'embed_date')
#     F1 Score=0.9259083939818409 | Length of Features:=5 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword')
#     F1 Score=0.925872823320421 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code')
#     F1 Score=0.925803785351674 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'puny_code')
#     F1 Score=0.9258010739012684 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.9257887944468001 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword')
#     F1 Score=0.9257555225726044 | Length of Features:=7 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9257498607302125 | Length of Features:=5 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.9257259405035658 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9257039736606061 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'embed_date')
#     F1 Score=0.9256988210441375 | Length of Features:=6 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9256982947045902 | Length of Features:=7 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9256982109226548 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.9256897173685046 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.925683364581548 | Length of Features:=7 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9256594782292893 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9256079001750169 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.925598848903995 | Length of Features:=6 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9255931351882992 | Length of Features:=6 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.9255870486146772 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9255683509188495 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'embed_date')
#     F1 Score=0.9255593830388011 | Length of Features:=5 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio')
#     F1 Score=0.9255503544934781 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9255498260577154 | Length of Features:=8 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.925517458388177 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.9251652009797388 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'puny_code')
#     F1 Score=0.9251464903293888 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.9251048209072943 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword')
#     F1 Score=0.9251017508355716 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'puny_code')
#     F1 Score=0.9250724124491494 | Length of Features:=7 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9250495140917898 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9250316309384266 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'embed_date')
#     F1 Score=0.9250166334014457 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'puny_code', 'embed_date')
#     F1 Score=0.9250134068944116 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9250076928777611 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9250036489502188 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'embed_date')
#     F1 Score=0.9249825723562479 | Length of Features:=5 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons')
#     F1 Score=0.9249625249320446 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.924956634043023 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9249391486685345 | Length of Features:=8 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9249301341899949 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.9249220461208403 | Length of Features:=6 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.9249037548445529 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9249013724951979 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9248981948316979 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.9248943010856822 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9248902303644939 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'embed_date')
#     F1 Score=0.9248674906606554 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9248645767642101 | Length of Features:=5 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9248447242496042 | Length of Features:=7 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9248445790247557 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio')
#     F1 Score=0.9248434417863276 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9248197496899992 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9248046978041626 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code')
#     F1 Score=0.9248012464598105 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.9247928912742459 | Length of Features:=8 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9247893897208002 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.924770412498183 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9247639194561128 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9247328488946074 | Length of Features:=7 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.924695658505471 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'embed_date')
#     F1 Score=0.9246707941669706 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'puny_code')
#     F1 Score=0.9246556925742129 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.9246143656869563 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9246131547465211 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.924581219809862 | Length of Features:=8 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9245034209469735 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword')
#     F1 Score=0.9244974826312703 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.9243847257969866 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.924358951425966 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9242442164828699 | Length of Features:=7 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio')
#     F1 Score=0.9242134761786482 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'embed_date')
#     F1 Score=0.9241239316976848 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9241048715089468 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9240867450657057 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'embed_date')
#     F1 Score=0.9240843918052256 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.9240651550582996 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword')
#     F1 Score=0.9240370916084106 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'puny_code', 'embed_date')
#     F1 Score=0.9240152653486765 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.924014266933155 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'embed_date')
#     F1 Score=0.9239930131867128 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio')
#     F1 Score=0.9239832460047095 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'embed_date')
#     F1 Score=0.9239778797555973 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.9239777145959799 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9239687154091107 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.9239424506899956 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.9239347929449716 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9239341554717567 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9239273606889036 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9239192114307105 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code')
#     F1 Score=0.923919099461688 | Length of Features:=7 | Features: ('length', 'entropy', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.9239151287369924 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio')
#     F1 Score=0.923915081625263 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.923896916752127 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9238542746416579 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9238459759791816 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.9238381747200283 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.9238298594537067 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code')
#     F1 Score=0.9238284026272975 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9238228154424585 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword')
#     F1 Score=0.9238170550954076 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'puny_code')
#     F1 Score=0.9238155140353352 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio')
#     F1 Score=0.9237982262159197 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9237959226309131 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9237897406350667 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.923786464397016 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'embed_date')
#     F1 Score=0.9237740285521003 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9237682279755036 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9237073195480171 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.9237003372260564 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword')
#     F1 Score=0.9236974108180661 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.9236695622695479 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword')
#     F1 Score=0.9236657209800988 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'embed_date')
#     F1 Score=0.9236537615177204 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'puny_code')
#     F1 Score=0.9236516791914575 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons')
#     F1 Score=0.9236338224877787 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code')
#     F1 Score=0.923623921103137 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'puny_code')
#     F1 Score=0.9236115483389957 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9236099226295206 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'embed_date')
#     F1 Score=0.9235752246160974 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'puny_code', 'embed_date')
#     F1 Score=0.9235740765888487 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.9235538132357517 | Length of Features:=6 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.923547764021353 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.923543865810071 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.9235358067028304 | Length of Features:=5 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'dword', 'embed_date')
#     F1 Score=0.9235307453073045 | Length of Features:=5 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'embed_date')
#     F1 Score=0.9235264139678054 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9235176091277657 | Length of Features:=5 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'puny_code', 'embed_date')
#     F1 Score=0.9235176091277657 | Length of Features:=4 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'embed_date')
#     F1 Score=0.9234756901340502 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9234617180963921 | Length of Features:=8 | Features: ('length', 'entropy', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9233825478520176 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.923296146444254 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword')
#     F1 Score=0.9232921352113284 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9231971896244138 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9231765599376711 | Length of Features:=6 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9231705604990751 | Length of Features:=7 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio')
#     F1 Score=0.9231696787541541 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9231528476930535 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9231364086684621 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'puny_code')
#     F1 Score=0.9231360281167827 | Length of Features:=7 | Features: ('length', 'entropy', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.9231335918135173 | Length of Features:=6 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.9231220267315493 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'embed_date')
#     F1 Score=0.923121363503639 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9231202015334425 | Length of Features:=8 | Features: ('length', 'entropy', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.9231135432404752 | Length of Features:=8 | Features: ('length', 'entropy', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9231006806111038 | Length of Features:=6 | Features: ('length', 'entropy', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.9230970231015047 | Length of Features:=6 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9230968887409672 | Length of Features:=5 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9230903725882893 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.9230884080132601 | Length of Features:=8 | Features: ('length', 'entropy', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9230844165825085 | Length of Features:=8 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9230695787491173 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword')
#     F1 Score=0.9230686109721399 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.923062587457977 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9230535890138174 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'embed_date')
#     F1 Score=0.923047243458311 | Length of Features:=5 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons')
#     F1 Score=0.9230352442909728 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'puny_code')
#     F1 Score=0.9230294083869476 | Length of Features:=7 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9230289298140708 | Length of Features:=7 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'puny_code', 'embed_date')
#     F1 Score=0.9230019113126706 | Length of Features:=8 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9230002270571285 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code')
#     F1 Score=0.9229953380035905 | Length of Features:=6 | Features: ('length', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'embed_date')
#     F1 Score=0.9229929223745403 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'embed_date')
#     F1 Score=0.9229913122474624 | Length of Features:=7 | Features: ('length', 'entropy', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.9229831795468545 | Length of Features:=7 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9229810049233851 | Length of Features:=7 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9229502044502519 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.9229355257434408 | Length of Features:=7 | Features: ('length', 'entropy', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'embed_date')
#     F1 Score=0.9229107797175636 | Length of Features:=5 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'dword')
#     F1 Score=0.9229104786201912 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9229076485042164 | Length of Features:=7 | Features: ('length', 'entropy', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword')
#     F1 Score=0.9228805521987574 | Length of Features:=5 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'puny_code')
#     F1 Score=0.9228799348372305 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'embed_date')
#     F1 Score=0.9228575571496526 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'puny_code')
#     F1 Score=0.9228456981033982 | Length of Features:=5 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'embed_date')
#     F1 Score=0.9228229696954132 | Length of Features:=4 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons')
#     F1 Score=0.9228180153798409 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'embed_date')
#     F1 Score=0.9228034421422443 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'puny_code')
#     F1 Score=0.9227771270625089 | Length of Features:=7 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9227726156976328 | Length of Features:=6 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.9227706151111705 | Length of Features:=8 | Features: ('length', 'entropy', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9227642381658885 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'embed_date')
#     F1 Score=0.9227551953918933 | Length of Features:=7 | Features: ('length', 'entropy', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.922750165578816 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.9227111965824916 | Length of Features:=8 | Features: ('length', 'entropy', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9227085914090949 | Length of Features:=7 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.9227067676647873 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9226846852655355 | Length of Features:=6 | Features: ('length', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'embed_date')
#     F1 Score=0.9226703985969641 | Length of Features:=7 | Features: ('length', 'entropy', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.9226403106555081 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'puny_code')
#     F1 Score=0.9226341401565719 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'embed_date')
#     F1 Score=0.922621132074274 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.9226177166819017 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'puny_code', 'embed_date')
#     F1 Score=0.9226070685265778 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9225974637058169 | Length of Features:=8 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.922596416980203 | Length of Features:=7 | Features: ('length', 'entropy', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.9225931308894009 | Length of Features:=7 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'embed_date')
#     F1 Score=0.9225774477689404 | Length of Features:=7 | Features: ('length', 'entropy', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code')
#     F1 Score=0.9225574790283378 | Length of Features:=6 | Features: ('length', 'entropy', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio')
#     F1 Score=0.9225243030334225 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'embed_date')
#     F1 Score=0.9225067382285743 | Length of Features:=6 | Features: ('length', 'entropy', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.922506606563154 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'puny_code', 'embed_date')
#     F1 Score=0.9225025748096524 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.9224932292151007 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'embed_date')
#     F1 Score=0.9224834458041385 | Length of Features:=7 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons')
#     F1 Score=0.9224738170917274 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.9224704733560225 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'embed_date')
#     F1 Score=0.9224669838731561 | Length of Features:=7 | Features: ('length', 'entropy', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9224554179914328 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword')
#     F1 Score=0.9224422203956617 | Length of Features:=7 | Features: ('length', 'entropy', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9224421225410095 | Length of Features:=7 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'puny_code')
#     F1 Score=0.922438842200141 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9224375155380067 | Length of Features:=7 | Features: ('length', 'entropy', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9224250122872496 | Length of Features:=7 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'embed_date')
#     F1 Score=0.9224006155836058 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9223986845366753 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9223925337227505 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9223790616938127 | Length of Features:=6 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'embed_date')
#     F1 Score=0.9223762967254029 | Length of Features:=7 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9223707955981271 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.9223653058903333 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'embed_date')
#     F1 Score=0.9223492082914009 | Length of Features:=6 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'embed_date')
#     F1 Score=0.9223489416767429 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9223115481458448 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.9223113325080486 | Length of Features:=6 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons')
#     F1 Score=0.922295542493788 | Length of Features:=7 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'embed_date')
#     F1 Score=0.9221793306485362 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9221588539150538 | Length of Features:=8 | Features: ('length', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.9221494365448718 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9221462390363093 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.9221366655470682 | Length of Features:=7 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword')
#     F1 Score=0.9221308855483927 | Length of Features:=7 | Features: ('length', 'entropy', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'embed_date')
#     F1 Score=0.9221182659842393 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.92211796293298 | Length of Features:=7 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.9221059972723975 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'puny_code', 'embed_date')
#     F1 Score=0.9220814047913866 | Length of Features:=8 | Features: ('length', 'entropy', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9220755617144457 | Length of Features:=7 | Features: ('length', 'entropy', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9220741801014725 | Length of Features:=7 | Features: ('length', 'entropy', 'vowel_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9220603929227789 | Length of Features:=8 | Features: ('length', 'entropy', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.9220296739451592 | Length of Features:=7 | Features: ('length', 'entropy', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit')
#     F1 Score=0.9220108914932592 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'embed_date')
#     F1 Score=0.9219869346740263 | Length of Features:=7 | Features: ('length', 'entropy', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9219843091577985 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'puny_code')
#     F1 Score=0.9219814889705594 | Length of Features:=8 | Features: ('length', 'entropy', 'vowel_ratio', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.9219777537407212 | Length of Features:=7 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'puny_code')
#     F1 Score=0.9219680675650336 | Length of Features:=7 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword')
#     F1 Score=0.9219580291531739 | Length of Features:=6 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons')
#     F1 Score=0.9219185501467608 | Length of Features:=7 | Features: ('entropy', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio')
#     F1 Score=0.9219004233266329 | Length of Features:=8 | Features: ('length', 'entropy', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9218857614424326 | Length of Features:=7 | Features: ('length', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'dword', 'embed_date')
#     F1 Score=0.9218828641830654 | Length of Features:=8 | Features: ('entropy', 'vowel_ratio', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'hex_ratio', 'puny_code')
#     F1 Score=0.9218365010149657 | Length of Features:=6 | Features: ('length', 'entropy', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9218362099213788 | Length of Features:=7 | Features: ('length', 'entropy', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit', 'embed_date')
#     F1 Score=0.9217994220487403 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.9217896679890171 | Length of Features:=6 | Features: ('length', 'entropy', 'digit_ratio', 'hyphen_count', 'max_consec_cons', 'max_consec_digit')
#     F1 Score=0.9217895903363209 | Length of Features:=8 | Features: ('length', 'entropy', 'digit_ratio', 'unique_chars', 'hyphen_count', 'max_consec_cons', 'dword', 'puny_code')
# ...
#     F1 Score=0.8264737555389235 | Length of Features:=7 | Features: ('digit_ratio', 'hyphen_count', 'hex_ratio', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.8263003267925164 | Length of Features:=6 | Features: ('digit_ratio', 'hyphen_count', 'hex_ratio', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.8262994132429572 | Length of Features:=6 | Features: ('digit_ratio', 'hyphen_count', 'hex_ratio', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.8258716818369853 | Length of Features:=5 | Features: ('digit_ratio', 'hyphen_count', 'hex_ratio', 'dword', 'embed_date')
#     F1 Score=0.8258311698852504 | Length of Features:=4 | Features: ('digit_ratio', 'hyphen_count', 'hex_ratio', 'embed_date')
#     F1 Score=0.8257754941787617 | Length of Features:=6 | Features: ('digit_ratio', 'hyphen_count', 'hex_ratio', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.8257549259785876 | Length of Features:=5 | Features: ('digit_ratio', 'hyphen_count', 'hex_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.8249466293383512 | Length of Features:=3 | Features: ('digit_ratio', 'hyphen_count', 'hex_ratio')
#     F1 Score=0.8247396499640564 | Length of Features:=4 | Features: ('digit_ratio', 'hyphen_count', 'hex_ratio', 'dword')
#     F1 Score=0.8246127894398333 | Length of Features:=5 | Features: ('digit_ratio', 'hyphen_count', 'hex_ratio', 'dword', 'puny_code')
#     F1 Score=0.8246106459856024 | Length of Features:=4 | Features: ('digit_ratio', 'hyphen_count', 'hex_ratio', 'puny_code')
#     F1 Score=0.822879627061492 | Length of Features:=3 | Features: ('unique_chars', 'puny_code', 'embed_date')
#     F1 Score=0.8228638377241649 | Length of Features:=4 | Features: ('unique_chars', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.822832046089367 | Length of Features:=3 | Features: ('unique_chars', 'dword', 'embed_date')
#     F1 Score=0.8199454958337979 | Length of Features:=3 | Features: ('vowel_ratio', 'digit_ratio', 'dword')
#     F1 Score=0.8198274579565711 | Length of Features:=3 | Features: ('vowel_ratio', 'digit_ratio', 'puny_code')
#     F1 Score=0.8198273671860502 | Length of Features:=4 | Features: ('vowel_ratio', 'digit_ratio', 'dword', 'puny_code')
#     F1 Score=0.8197586145917658 | Length of Features:=3 | Features: ('max_consec_cons', 'dword', 'puny_code')
#     F1 Score=0.8197506937588959 | Length of Features:=4 | Features: ('max_consec_cons', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.8197330472188206 | Length of Features:=3 | Features: ('max_consec_cons', 'puny_code', 'embed_date')
#     F1 Score=0.8197155398945576 | Length of Features:=3 | Features: ('max_consec_cons', 'dword', 'embed_date')
#     F1 Score=0.8185191547029642 | Length of Features:=4 | Features: ('vowel_ratio', 'digit_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.8184665738458697 | Length of Features:=4 | Features: ('vowel_ratio', 'digit_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.8180168276640588 | Length of Features:=3 | Features: ('vowel_ratio', 'digit_ratio', 'max_consec_digit')
#     F1 Score=0.8179257416259537 | Length of Features:=5 | Features: ('vowel_ratio', 'digit_ratio', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.8175152396454518 | Length of Features:=5 | Features: ('vowel_ratio', 'digit_ratio', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.8174123589270144 | Length of Features:=5 | Features: ('vowel_ratio', 'digit_ratio', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.817283383660984 | Length of Features:=4 | Features: ('vowel_ratio', 'digit_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.817159613265995 | Length of Features:=6 | Features: ('vowel_ratio', 'digit_ratio', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.8171301349379313 | Length of Features:=5 | Features: ('vowel_ratio', 'digit_ratio', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.817011738275737 | Length of Features:=4 | Features: ('vowel_ratio', 'digit_ratio', 'dword', 'embed_date')
#     F1 Score=0.8169243007788634 | Length of Features:=4 | Features: ('vowel_ratio', 'digit_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.8168653348588473 | Length of Features:=3 | Features: ('vowel_ratio', 'digit_ratio', 'embed_date')
#     F1 Score=0.8159057100835669 | Length of Features:=5 | Features: ('hyphen_count', 'hex_ratio', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.8158512587637923 | Length of Features:=6 | Features: ('hyphen_count', 'hex_ratio', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.815504015603209 | Length of Features:=4 | Features: ('hyphen_count', 'hex_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.8154258506330336 | Length of Features:=5 | Features: ('hyphen_count', 'hex_ratio', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.8095720717008767 | Length of Features:=4 | Features: ('hyphen_count', 'hex_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.8095329901180726 | Length of Features:=5 | Features: ('hyphen_count', 'hex_ratio', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.809243835798888 | Length of Features:=4 | Features: ('hyphen_count', 'hex_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.8091821297141012 | Length of Features:=3 | Features: ('hyphen_count', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.8041901753955157 | Length of Features:=3 | Features: ('unique_chars', 'dword', 'puny_code')
#     F1 Score=0.79504802544936 | Length of Features:=4 | Features: ('vowel_ratio', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.794995919029097 | Length of Features:=3 | Features: ('vowel_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.7949729510184795 | Length of Features:=5 | Features: ('vowel_ratio', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.79494841327347 | Length of Features:=4 | Features: ('vowel_ratio', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.7918592077038458 | Length of Features:=4 | Features: ('vowel_ratio', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.7917489447000562 | Length of Features:=3 | Features: ('vowel_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.7917022094316049 | Length of Features:=3 | Features: ('vowel_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.7911001668207223 | Length of Features:=4 | Features: ('hyphen_count', 'hex_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.7911001668207223 | Length of Features:=3 | Features: ('hyphen_count', 'hex_ratio', 'embed_date')
#     F1 Score=0.7911001668207223 | Length of Features:=5 | Features: ('hyphen_count', 'hex_ratio', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.7911001668207223 | Length of Features:=4 | Features: ('hyphen_count', 'hex_ratio', 'dword', 'embed_date')
#     F1 Score=0.7875384001144277 | Length of Features:=4 | Features: ('digit_ratio', 'hex_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.7872644058317978 | Length of Features:=4 | Features: ('digit_ratio', 'hex_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.7871317169983963 | Length of Features:=5 | Features: ('digit_ratio', 'hex_ratio', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.7870255909098532 | Length of Features:=3 | Features: ('digit_ratio', 'hex_ratio', 'max_consec_digit')
#     F1 Score=0.785294021364291 | Length of Features:=4 | Features: ('digit_ratio', 'hex_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.7852417917542518 | Length of Features:=4 | Features: ('digit_ratio', 'hex_ratio', 'dword', 'puny_code')
#     F1 Score=0.7851723642749451 | Length of Features:=3 | Features: ('digit_ratio', 'hex_ratio', 'dword')
#     F1 Score=0.7851292929692222 | Length of Features:=3 | Features: ('digit_ratio', 'hex_ratio', 'puny_code')
#     F1 Score=0.7851217010398737 | Length of Features:=5 | Features: ('digit_ratio', 'hex_ratio', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.7850401466059084 | Length of Features:=6 | Features: ('digit_ratio', 'hex_ratio', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.7849756444794469 | Length of Features:=5 | Features: ('digit_ratio', 'hex_ratio', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.7844332674823563 | Length of Features:=4 | Features: ('digit_ratio', 'hex_ratio', 'dword', 'embed_date')
#     F1 Score=0.7842750808255715 | Length of Features:=3 | Features: ('digit_ratio', 'hex_ratio', 'embed_date')
#     F1 Score=0.7841790267289623 | Length of Features:=5 | Features: ('digit_ratio', 'hex_ratio', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.7841399881461298 | Length of Features:=4 | Features: ('digit_ratio', 'hex_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.7833855482849694 | Length of Features:=3 | Features: ('hyphen_count', 'hex_ratio', 'puny_code')
#     F1 Score=0.7833698441379852 | Length of Features:=4 | Features: ('hyphen_count', 'hex_ratio', 'dword', 'puny_code')
#     F1 Score=0.7833698441379852 | Length of Features:=3 | Features: ('hyphen_count', 'hex_ratio', 'dword')
#     F1 Score=0.7772963753401136 | Length of Features:=3 | Features: ('vowel_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.7772803883352216 | Length of Features:=4 | Features: ('vowel_ratio', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.7772643594573952 | Length of Features:=3 | Features: ('vowel_ratio', 'dword', 'embed_date')
#     F1 Score=0.7744743011190701 | Length of Features:=6 | Features: ('digit_ratio', 'hyphen_count', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.7744622203012059 | Length of Features:=5 | Features: ('digit_ratio', 'hyphen_count', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.7744288945179674 | Length of Features:=5 | Features: ('digit_ratio', 'hyphen_count', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.7744066999470807 | Length of Features:=4 | Features: ('digit_ratio', 'hyphen_count', 'max_consec_digit', 'embed_date')
#     F1 Score=0.7718213235630096 | Length of Features:=3 | Features: ('digit_ratio', 'hyphen_count', 'max_consec_digit')
#     F1 Score=0.771763402421248 | Length of Features:=5 | Features: ('digit_ratio', 'hyphen_count', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.771741891119764 | Length of Features:=4 | Features: ('digit_ratio', 'hyphen_count', 'max_consec_digit', 'puny_code')
#     F1 Score=0.7716862967686744 | Length of Features:=4 | Features: ('digit_ratio', 'hyphen_count', 'dword', 'max_consec_digit')
#     F1 Score=0.7696882576155468 | Length of Features:=4 | Features: ('hex_ratio', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.7696724525906191 | Length of Features:=5 | Features: ('hex_ratio', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.7692439268255578 | Length of Features:=4 | Features: ('hex_ratio', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.7691619658223323 | Length of Features:=3 | Features: ('hex_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.7691024134420782 | Length of Features:=5 | Features: ('digit_ratio', 'hyphen_count', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.7691024134420782 | Length of Features:=4 | Features: ('digit_ratio', 'hyphen_count', 'dword', 'embed_date')
#     F1 Score=0.769068385887705 | Length of Features:=4 | Features: ('digit_ratio', 'hyphen_count', 'puny_code', 'embed_date')
#     F1 Score=0.769068385887705 | Length of Features:=3 | Features: ('digit_ratio', 'hyphen_count', 'embed_date')
#     F1 Score=0.7662158602271043 | Length of Features:=3 | Features: ('vowel_ratio', 'dword', 'puny_code')
#     F1 Score=0.7643277215426861 | Length of Features:=4 | Features: ('digit_ratio', 'hyphen_count', 'dword', 'puny_code')
#     F1 Score=0.7643231224959729 | Length of Features:=3 | Features: ('digit_ratio', 'hyphen_count', 'puny_code')
#     F1 Score=0.7643157002151064 | Length of Features:=3 | Features: ('digit_ratio', 'hyphen_count', 'dword')
#     F1 Score=0.7603985644171163 | Length of Features:=4 | Features: ('hex_ratio', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.7603060294581416 | Length of Features:=3 | Features: ('hex_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.7600436937555404 | Length of Features:=3 | Features: ('hex_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.743388046563904 | Length of Features:=3 | Features: ('hex_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.7433723727106886 | Length of Features:=4 | Features: ('hex_ratio', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.7433413564921298 | Length of Features:=3 | Features: ('hex_ratio', 'dword', 'embed_date')
#     F1 Score=0.7417260127714183 | Length of Features:=4 | Features: ('digit_ratio', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.7416496840181728 | Length of Features:=3 | Features: ('digit_ratio', 'max_consec_digit', 'embed_date')
#     F1 Score=0.7416306224674749 | Length of Features:=4 | Features: ('digit_ratio', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.7415622040994398 | Length of Features:=5 | Features: ('digit_ratio', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.7403567908669035 | Length of Features:=4 | Features: ('digit_ratio', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.7403342925740636 | Length of Features:=3 | Features: ('digit_ratio', 'max_consec_digit', 'puny_code')
#     F1 Score=0.7403310187927483 | Length of Features:=3 | Features: ('digit_ratio', 'dword', 'max_consec_digit')
#     F1 Score=0.7369916621156113 | Length of Features:=3 | Features: ('hex_ratio', 'dword', 'puny_code')
#     F1 Score=0.7361657812278353 | Length of Features:=4 | Features: ('hyphen_count', 'dword', 'max_consec_digit', 'puny_code')
#     F1 Score=0.736165657353252 | Length of Features:=3 | Features: ('hyphen_count', 'dword', 'max_consec_digit')
#     F1 Score=0.7359820515623511 | Length of Features:=4 | Features: ('digit_ratio', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.7359485054394085 | Length of Features:=3 | Features: ('digit_ratio', 'dword', 'embed_date')
#     F1 Score=0.7359293533419311 | Length of Features:=3 | Features: ('digit_ratio', 'puny_code', 'embed_date')
#     F1 Score=0.7357013291702719 | Length of Features:=3 | Features: ('hyphen_count', 'max_consec_digit', 'puny_code')
#     F1 Score=0.7317090902729995 | Length of Features:=4 | Features: ('hyphen_count', 'dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.7317007777346058 | Length of Features:=5 | Features: ('hyphen_count', 'dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.7313679314193676 | Length of Features:=4 | Features: ('hyphen_count', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.731356563240466 | Length of Features:=3 | Features: ('hyphen_count', 'max_consec_digit', 'embed_date')
#     F1 Score=0.7306482220016101 | Length of Features:=3 | Features: ('digit_ratio', 'dword', 'puny_code')
#     F1 Score=0.7249790765974992 | Length of Features:=3 | Features: ('hyphen_count', 'dword', 'puny_code')
#     F1 Score=0.7173499024154057 | Length of Features:=4 | Features: ('hyphen_count', 'dword', 'puny_code', 'embed_date')
#     F1 Score=0.7173389908718841 | Length of Features:=3 | Features: ('hyphen_count', 'dword', 'embed_date')
#     F1 Score=0.7170508721851053 | Length of Features:=3 | Features: ('hyphen_count', 'puny_code', 'embed_date')
#     F1 Score=0.6872889143641829 | Length of Features:=4 | Features: ('dword', 'max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.6872475946344238 | Length of Features:=3 | Features: ('dword', 'max_consec_digit', 'embed_date')
#     F1 Score=0.6870293173989663 | Length of Features:=3 | Features: ('max_consec_digit', 'puny_code', 'embed_date')
#     F1 Score=0.6739622557102488 | Length of Features:=3 | Features: ('dword', 'puny_code', 'embed_date')
#     F1 Score=0.6683100237533048 | Length of Features:=3 | Features: ('dword', 'max_consec_digit', 'puny_code')

# %%
best_score, best_combo = results[0]
X_best = df[list(best_combo)]
y = df["label"]
X_train, X_test, y_train, y_test = train_test_split(X_best, y, test_size=0.2, random_state=60)
scores = {}

# %%
roc_auc_fpr(65, 10, 14, 65, X_train, y_train, X_test, y_test)
# Out:
# Accuracy (n=65):
# 	False Positive Rate: 0.09870 (9.870%)
# 	False Negative Rate: 0.05411 (5.411%)
# 	True Negatives=14400, False Positives=1577, False Negatives=867, True Positives=15156
#
# Precision (n=10):
# 	False Positive Rate: 0.09770 (9.770%)
# 	False Negative Rate: 0.05573 (5.573%)
# 	True Negatives=14416, False Positives=1561, False Negatives=893, True Positives=15130
#
# Recall (n=14):
# 	False Positive Rate: 0.10258 (10.258%)
# 	False Negative Rate: 0.05174 (5.174%)
# 	True Negatives=14338, False Positives=1639, False Negatives=829, True Positives=15194
#
# F1 Score (n=65):
# 	False Positive Rate: 0.09870 (9.870%)
# 	False Negative Rate: 0.05411 (5.411%)
# 	True Negatives=14400, False Positives=1577, False Negatives=867, True Positives=15156
